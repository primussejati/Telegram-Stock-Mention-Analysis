# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth',10000)

# %%
chat = pd.read_json('Sample Data/result.json')
chat
# Out:
#                     name               type          id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       messages
# ...

# %%
chat[['messages']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            messages
# ...
